# %%
import random
from IPython.display import Image, display
import time

choice = ["Joey", "Sniswa", "Annika", "Yana"] 
memes = ['mem1.jpg', 'mem2.jpg', 'mem3.jpg', 'mem4.jpg', 'mem5.jpg', 'mem6.jpg', 'mem7.jpg', 'mem8.jpg', 'mem9.jpg']
goon_choice = random.choice(choice)
random_memes = random.choice(memes)
while True:
    if goon_choice == "Joey":
        print("Iw nigga you gay!")
        display(Image(filename=random_memes))
        break
    elif goon_choice == "Sniswa":
        guess = str(input("Is a Femboy or a fineshyst? ")).lower()
        if guess == "fineshyt":
            print("You are right my boy! Goon time!")
            random_memes = random.choice(memes)
            display(Image(filename=random_memes))
            break
        else:
            print("Nigga you gay asf fuck!")
            random_memes = random.choice(memes)
            display(Image(filename=random_memes))

            break
    elif goon_choice == "Annika":
        print("Give me a random fineshyt rizz. Remember shooter shoot!")
        rizz = str(input("Give me somee on your books! ")).lower()
        random_fineshyt_response = ["Get my number bae!", "Get the fuck out of my face imma call the police", "Iwwww shitt!", "airrrrrrball nigga!"]
        if len(random_fineshyt_response) == 0:
            print("you lil bro you got some shyts on you huh!")
            random_memes = random.choice(memes)
            display(Image(filename=random_memes))

            continue
        elif len(random_fineshyt_response) == 1:
            print("Get the fuck out here weirdooo!! Better do not comeback here imma shot yo head")
            random_memes = random.choice(memes)
            display(Image(filename=random_memes))

            break
        elif len(random_fineshyt_response) == 2:
            print("Stranger Danger! Stranger Danger!")
            random_memes = random.choice(memes)
            display(Image(filename=random_memes))

            break
        else:
            print("Air ball nigga! you still don't have game, fucking losers!")
            random_memes = random.choice(memes)
            display(Image(filename=random_memes))
            break

    elif goon_choice == "Yana":
        print("Fuck here we go again! Goon cancel! I remember her again!")
        lyrics = [
        "Tensionado nagulat din ako",
        "Nung malaman na hindi lang pala ako",
        "Yung nanghinayang nung nag away tayo nun",
        "At natuluyan sa iyakan at tampo",
        "At sandali lang 'wag ka munang magsalita",
        "'Di ko hahayaang lahat ito ay mawala",
        "Ang iniisip ko",
        "Kung pwede pa ba tayo",
        "At miserable paulit-ulit lang",
        "Ang nangyayari paikot-ikot tayo",
        "Parang bote at nasanay ka na ba don",
        "At nalimutan ang aking mga tanong",
        "At kundi malinaw pwede bang wag kang sumigaw",
        "'Di ko hahayaan lahat ito ay maligaw",
        "Nagtatanong sayo",
        "Kung pwede pa ba tayo",
        "At sandali lang 'wag ka munang magsalita",
        "'Di ko hahayaan lahat ito ay mawala",
        "At sandali lang 'wag ka munang magsalita",
        "Ba't ko hahayaang pati ikaw ay mawala",
        "Nagtatanong sayo",
        "Kung pwede pa ba tayo"
]
        
        for i in lyrics:
         print(i)
         time.sleep(1.5)
        print("time to sleep nigga!")
        random_memes = random.choice(memes)
        display(Image(filename=random_memes))

        break
# Out:
# Fuck here we go again! Goon cancel! I remember her again!
# Tensionado nagulat din ako
# Nung malaman na hindi lang pala ako
# Yung nanghinayang nung nag away tayo nun
# At natuluyan sa iyakan at tampo
# At sandali lang 'wag ka munang magsalita
# 'Di ko hahayaang lahat ito ay mawala
# Ang iniisip ko
# Kung pwede pa ba tayo
# At miserable paulit-ulit lang
# Ang nangyayari paikot-ikot tayo
# Parang bote at nasanay ka na ba don
# At nalimutan ang aking mga tanong
# At kundi malinaw pwede bang wag kang sumigaw
# 'Di ko hahayaan lahat ito ay maligaw
# Nagtatanong sayo
# Kung pwede pa ba tayo
# At sandali lang 'wag ka munang magsalita
# 'Di ko hahayaan lahat ito ay mawala
# At sandali lang 'wag ka munang magsalita
# Ba't ko hahayaang pati ikaw ay mawala
# Nagtatanong sayo
# Kung pwede pa ba tayo
# time to sleep nigga!
